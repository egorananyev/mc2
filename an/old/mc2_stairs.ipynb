# %%
## Preparing the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, glob
from matplotlib import cm
import psychopy
from psychopy.tools.filetools import fromFile

# %% [markdown]
# Loading the data:

# %%
# %matplotlib inline
plt.style.use('dark_background')
expName = 'mc2_tgT-mcBv'
#condName = 'mc2_tgT-mcBv_peri'
dataDir = os.path.abspath(os.path.join(os.getcwd(), '..', '..', 'data/', expName + '*'))
print dataDir
allSubjDirs = glob.glob(dataDir + '/' + expName + '*')
print allSubjDirs
stairs = pd.DataFrame()
# matrices for intensities, responses, and means of reversals:
intns, resps, thisRevs, revMeans = [],[],[],[] 
orderInfo = pd.DataFrame() # subj, session, and stair info for ordering intns & resps
# Out:
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv*
# ['C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_cent_p0_s1_2017-01-26_1545', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_cent_p11_s1_2017-02-08_1635', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_cent_p14_s1_2017-02-15_1115', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_cent_p3_s1_2017-01-31_1514', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_cent_p4_s2_2017-02-02_1303', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_cent_p5_s4_2017-02-07_1220', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_cent_p6_s4_2017-02-11_1549', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-c_p0_s3_2017-01-31_1052', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-c_p13_s1_2017-02-14_1637', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-c_p15_s1_2017-02-15_1630', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-c_p3_s2_2017-02-02_1133', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-c_p4_s4_2017-02-14_1434', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-c_p5_s2_2017-02-07_1008', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-c_p6_s1_2017-02-04_1514', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-p_p0_s4_2017-01-31_1225', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-p_p3_s4_2017-02-07_1306', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-p_p4_s3_2017-02-07_1504', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-p_p5_s1_2017-02-02_1643', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-p_p6_s3_2017-02-11_1516', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_mtn-p_p8_s1_2017-02-15_1435', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_peri_p0_s2_2017-01-26_1252', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_peri_p3_s3_2017-02-02_1206', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_peri_p4_s1_2017-01-31_1642', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_peri_p5_s3_2017-02-07_1116', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv\\mc2_tgT-mcBv_peri_p6_s2_2017-02-11_1444', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_cent_p0_s1_2017-02-18_1046', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_cent_p13_s1_2017-02-22_1102', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_cent_p16_s2_2017-02-18_1401', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_cent_p17_s1_2017-02-18_1452', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_cent_p18_s2_2017-02-18_1703', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_cent_p19_s2_2017-02-20_1333', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_cent_p1_s2_2017-02-21_1439', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_cent_p20_s1_2017-02-21_1508', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_cent_p2_s1_2017-02-23_1144', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_cent_p9_s1_2017-02-20_1039', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_peri_p0_s2_2017-02-18_1114', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_peri_p13_s2_2017-02-23_1059', 'C:\\Users\\Egor\\Dropbox\\Projects\\mc\\data\\mc2_tgT-mcBv2\\mc2_tgT-mcBv2_peri_p14_s1_2017-02-22_1002', 'C:\\Users\\Egor\\Dropbox\\Project ...

# %%
for subjDir in allSubjDirs:
    print subjDir
    subjStairsPath = glob.glob(subjDir + '/' + expName + '*.csv')[0]
    subjStairs = pd.read_csv(subjStairsPath)
    stairs = stairs.append(subjStairs)
    #print subjStairs
    for subjStairLabel in subjStairs['stairLabel']:
        #print subjStairLabel #thisSubjStair['label']
        thisStair = fromFile(subjDir + '/' + subjStairLabel + '.psydat')
        intns.append(thisStair.intensities)
        resps.append(thisStair.data)
        theseRevIntns = thisStair.reversalIntensities #detectRevs(thisStair)
        #print np.round(theseRevIntns,1)
        revMeans.append([np.average(thisStair.reversalIntensities[-4:]),
                         np.average(thisStair.reversalIntensities[-6:]),
                         np.average(thisStair.reversalIntensities[-8:])])
        orderInfo = orderInfo.append(pd.DataFrame({
                    'participant': subjStairs.participant[0],
                    'mcBv': thisStair.extraInfo['mcBv'],
                    'targTpeak': thisStair.extraInfo['targTpeak'],
                    'targXoff2': thisStair.extraInfo['targXoff2'],
                    'targV': thisStair.extraInfo['targV'],
                    'stairStart': [thisStair.extraInfo['startContr']]
                    }))
                    #'sessionLabel': os.path.basename(subjStairsPath)[:-20],
                    #'stairLabel': [subjStairLabel]
        #print np.round(thisStair.intensities,2)
        #print thisStair.data # responses (correct/incorrect)
        #print thisStair.extraInfo
# Out:
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_cent_p0_s1_2017-01-26_1545
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_cent_p11_s1_2017-02-08_1635
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_cent_p14_s1_2017-02-15_1115
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_cent_p3_s1_2017-01-31_1514
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_cent_p4_s2_2017-02-02_1303
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_cent_p5_s4_2017-02-07_1220
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_cent_p6_s4_2017-02-11_1549
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-c_p0_s3_2017-01-31_1052
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-c_p13_s1_2017-02-14_1637
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-c_p15_s1_2017-02-15_1630
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-c_p3_s2_2017-02-02_1133
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-c_p4_s4_2017-02-14_1434
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-c_p5_s2_2017-02-07_1008
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-c_p6_s1_2017-02-04_1514
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-p_p0_s4_2017-01-31_1225
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-p_p3_s4_2017-02-07_1306
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-p_p4_s3_2017-02-07_1504
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-p_p5_s1_2017-02-02_1643
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-p_p6_s3_2017-02-11_1516
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_mtn-p_p8_s1_2017-02-15_1435
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_peri_p0_s2_2017-01-26_1252
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_peri_p3_s3_2017-02-02_1206
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_peri_p4_s1_2017-01-31_1642
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_peri_p5_s3_2017-02-07_1116
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv\mc2_tgT-mcBv_peri_p6_s2_2017-02-11_1444
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_cent_p0_s1_2017-02-18_1046
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_cent_p13_s1_2017-02-22_1102
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_cent_p16_s2_2017-02-18_1401
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_cent_p17_s1_2017-02-18_1452
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_cent_p18_s2_2017-02-18_1703
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_cent_p19_s2_2017-02-20_1333
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_cent_p1_s2_2017-02-21_1439
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_cent_p20_s1_2017-02-21_1508
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_cent_p2_s1_2017-02-23_1144
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_cent_p9_s1_2017-02-20_1039
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_peri_p0_s2_2017-02-18_1114
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_peri_p13_s2_2017-02-23_1059
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_peri_p14_s1_2017-02-22_1002
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_peri_p16_s1_2017-02-18_1338
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_peri_p17_s2_2017-02-18_1525
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_peri_p18_s1_2017-02-18_1633
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_peri_p19_s1_2017-02-20_1312
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_peri_p1_s1_2017-02-21_1410
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_peri_p20_s2_2017-02-21_1540
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_peri_p2_s2_2017-02-23_1216
# C:\Users\Egor\Dropbox\Projects\mc\data\mc2_tgT-mcBv2\mc2_tgT-mcBv2_peri_p9_s2_2017-02-20_1107

# %%
stairs['condLabel'] = 'mcBv-' + stairs.mcBv.astype(str) + '_' + \
                      'tgEcc-' + stairs.targXoff2.astype(str) + '_' + \
                      'tgV-' + stairs.targV.astype(str) + '_' + \
                      'tgT-' + stairs.targTpeak.astype(str)
print stairs.shape
print stairs.columns
stairs.head(5)
# Out:
# (870, 30)
# Index([u'dom', u'expName', u'expPara', u'fixCross', u'mcBsf', u'mcBv',
#        u'mcPeriFade', u'mcPeriGap', u'mcSf', u'mcSz', u'meanRev6', u'nRevs',
#        u'participant', u'session', u'stairLabel', u'stairMean', u'stairStart',
#        u'targOri1', u'targOri2', u'targSf', u'targSz', u'targTpeak',
#        u'targTtot', u'targV', u'targXoff1', u'targXoff2', u'targYoff', u'time',
#        u'trialT', u'condLabel'],
#       dtype='object')
#    dom            expName expPara  fixCross  mcBsf  mcBv  mcPeriFade  \
# 0  NaN  mc2_tgT-mcBv_cent     NaN         1   0.05  0.60          16
# 1  NaN  mc2_tgT-mcBv_cent     NaN         1   0.05  0.01          16
# 2  NaN  mc2_tgT-mcBv_cent     NaN         1   0.05  9.60          16
# 3  NaN  mc2_tgT-mcBv_cent     NaN         1   0.05  0.01          16
# 4  NaN  mc2_tgT-mcBv_cent     NaN         1   0.05  9.60          16
#
#    mcPeriGap  mcSf  mcSz                 ...                  targSz  \
# 0        112   0.1   256                 ...                      32
# 1        112   0.1   256                 ...                      32
# 2        112   0.1   256                 ...                      32
# 3        112   0.1   256                 ...                      32
# 4        112   0.1   256                 ...                      32
#
#    targTpeak  targTtot  targV targXoff1  targXoff2  targYoff             time  \
# 0        1.0       1.0    0.0       -48         48         0  2017-01-26_1545
# 1        1.0       1.0    0.0       -48         48         0  2017-01-26_1545
# 2        1.0       1.0    0.0       -48         48         0  2017-01-26_1545
# 3        1.5       1.0    0.0       -48         48         0  2017-01-26_1545
# 4        0.5       1.0    0.0       -48         48         0  2017-01-26_1545
#
#    trialT                           condLabel
# 0       2   mcBv-0.6_tgEcc-48_tgV-0.0_tgT-1.0
# 1       2  mcBv-0.01_tgEcc-48_tgV-0.0_tgT-1.0
# 2       2   mcBv-9.6_tgEcc-48_tgV-0.0_tgT-1.0
# 3       2  mcBv-0.01_tgEcc-48_tgV-0.0_tgT-1.5
# 4       2   mcBv-9.6_tgEcc-48_tgV-0.0_tgT-0.5
#
# [5 rows x 30 columns]

# %%
print np.shape(resps)
print np.shape(intns)
print np.shape(revMeans)
orderInfo = orderInfo.reset_index(drop=True)
print orderInfo.shape
orderInfo.head(5)
# Out:
# (870L,)
# (870L,)
# (870L, 3L)
# (870, 6)
#    mcBv  participant  stairStart  targTpeak  targV  targXoff2
# 0  0.60            0        -3.0        1.0    0.0         48
# 1  0.01            0        -3.0        1.0    0.0         48
# 2  9.60            0         0.0        1.0    0.0         48
# 3  0.01            0         0.0        1.5    0.0         48
# 4  9.60            0        -3.0        0.5    0.0         48

# %% [markdown]
# Combining the trial data into a tall df.

# %%
nStairs = np.shape(resps)[0]
nTrials = []
for thisResp in resps: nTrials.append(np.shape(thisResp)[0])
nTrialsMax = np.max(nTrials)
allResps, allIntns = [], []
for i in range(nStairs):
    thisResp, thisIntn = resps[i], intns[i]
    x, y = np.empty((nTrialsMax,)), np.empty((nTrialsMax,))
    x[:], y[:] = np.NAN, np.NAN
    x[0:nTrials[i]] = np.array(thisResp)
    y[0:nTrials[i]] = np.array(thisIntn)
    allResps.append(x)
    allIntns.append(y)
orderInfoRepd = orderInfo.loc[np.repeat(orderInfo.index.values,nTrialsMax)]
print orderInfoRepd.shape
orderInfoRepd = orderInfoRepd.reset_index(drop=True)
orderInfoRepd['trialN'] = np.tile(np.linspace(1,nTrialsMax,nTrialsMax),nStairs)
orderInfoRepd['intns'] = np.array(allIntns).flatten()
orderInfoRepd['resps'] = np.array(allResps).flatten()
trials = pd.merge(orderInfoRepd, stairs, on=['participant','mcBv','targTpeak',
                                             'targXoff2', 'targV', 'stairStart'])
trials.head(5)
# Out:
# (44370, 6)
#    mcBv  participant  stairStart  targTpeak  targV  targXoff2  trialN  intns  \
# 0   0.6            0        -3.0        1.0    0.0         48     1.0   -3.0
# 1   0.6            0        -3.0        1.0    0.0         48     2.0   -2.0
# 2   0.6            0        -3.0        1.0    0.0         48     3.0   -3.0
# 3   0.6            0        -3.0        1.0    0.0         48     4.0   -2.0
# 4   0.6            0        -3.0        1.0    0.0         48     5.0   -2.0
#
#    resps  dom                ...                 targOri1 targOri2  targSf  \
# 0    0.0  NaN                ...                        0        0     0.1
# 1    1.0  NaN                ...                        0        0     0.1
# 2    0.0  NaN                ...                        0        0     0.1
# 3    1.0  NaN                ...                        0        0     0.1
# 4    1.0  NaN                ...                        0        0     0.1
#
#    targSz  targTtot  targXoff1  targYoff             time  trialT  \
# 0      32       1.0        -48         0  2017-01-26_1545       2
# 1      32       1.0        -48         0  2017-01-26_1545       2
# 2      32       1.0        -48         0  2017-01-26_1545       2
# 3      32       1.0        -48         0  2017-01-26_1545       2
# 4      32       1.0        -48         0  2017-01-26_1545       2
#
#                            condLabel
# 0  mcBv-0.6_tgEcc-48_tgV-0.0_tgT-1.0
# 1  mcBv-0.6_tgEcc-48_tgV-0.0_tgT-1.0
# 2  mcBv-0.6_tgEcc-48_tgV-0.0_tgT-1.0
# 3  mcBv-0.6_tgEcc-48_tgV-0.0_tgT-1.0
# 4  mcBv-0.6_tgEcc-48_tgV-0.0_tgT-1.0
#
# [5 rows x 33 columns]

# %%
dfStatCent = trials.ix[(trials.targXoff2==48) & (trials.targV==0)]
dfStatPeri = trials.ix[(trials.targXoff2==104) & (trials.targV==0)]
dfMtnCent = trials.ix[(trials.targXoff2==48) & (trials.targV==3.5)]
dfMtnPeri = trials.ix[(trials.targXoff2==104) & (trials.targV==3.5)]

# %%
g = sns.factorplot(x='trialN', y='intns', hue='stairLabel', col='participant', data=dfStatCent, 
               col_wrap=2, ci=None, kind='point', size=5, scale=.6)
g.set_axis_labels('Trial','Contrast')
g.set(xticks=[])
#plt.ylim(-0.1,1.1)

# %%
g = sns.factorplot(x='trialN', y='intns', hue='stairLabel', col='participant', data=dfStatPeri, 
               col_wrap=2, ci=None, kind='point', size=5, scale=.6)
g.set_axis_labels('Trial','Contrast')
g.set(xticks=[])
#plt.ylim(-0.1,1.1)

# %%
g = sns.factorplot(x='trialN', y='intns', hue='stairLabel', col='participant', data=dfMtnCent, 
               col_wrap=2, ci=None, kind='point', size=5, scale=.6)
g.set_axis_labels('Trial','Contrast')
g.set(xticks=[])
#plt.ylim(-0.1,1.1)

# %%
g = sns.factorplot(x='trialN', y='intns', hue='stairLabel', col='participant', data=dfMtnPeri, 
               col_wrap=2, ci=None, kind='point', size=5, scale=.6)
g.set_axis_labels('Trial','Contrast')
g.set(xticks=[])
#plt.ylim(-0.1,1.1)

# %%
g = sns.factorplot(x='trialN', y='intns', hue='stairLabel', col='participant',
                   data=dfMtnCent.ix[(dfMtnCent.mcBv==0.6)&(dfMtnCent.targTpeak==1.5)], 
               col_wrap=2, ci=None, kind='point', size=5, scale=.6)
g.set_axis_labels('Trial','Contrast')
g.set(xticks=[])
#plt.ylim(-0.1,1.1)
